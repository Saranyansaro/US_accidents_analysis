# %% [markdown]
# # Define business problem statement from the identified Dataset.
#
#
# *   In US there are lots of accidents happening due to many circumstances.
# *   Many cities like Miami etc, have more number of accidents.

# %% [markdown]
# # A brief overview of the dataset.
#
#
# *   This is a dataset of US-accidents from 2016 to 2021.
# *   This dataset has 2845342 rows and 47 columns
# *   And it has various number of attributes like city, state, weather_conditions etc.

# %% [markdown]
# # Explanation of Problem statement and objectives.
#
# ## Problem Statement
# *   The many problem is accidents are happening a lot more in many cites and states because of certain situations.
#
# ## Objectives
# *   We can change the traffics rules
# *   Adding more number of break breakers
# *   Speed Limit
# *   Making Strict Rules & Regulations

# %%
# Jovian Commit Essentials
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('us-accidents-analysis')
jovian.set_colab_id('1A78hL3F6SedEblquDWRBon2QCdzQH8_z')
# Out:
#      |████████████████████████████████| 68 kB 6.2 MB/s
# ...

# %% [markdown]
# # us-accidents-analysis Exploratory Data Analysis
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit(project="us-accidents-analysis")
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY: ··········
# [jovian] Uploading colab notebook to Jovian...
# Committed successfully! https://jovian.ai/saranyan-g/us-accidents-analysis
# 'https://jovian.ai/saranyan-g/us-accidents-analysis'

# %% [markdown]
# # **US Accidents Exploratory Data Analysis**
#
# TODO - talk about EDA
#
#
# TODO - talk about the dataset (source, what it contains, how it will be useful)
#
# *   Kaggle
# *   Information about accidents
# *   Can use useful to prevent accidents
# *   Mention that this does not contain data about New York

# %% [markdown]
# # **Download the Data**

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od

download_url = 'https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents'

od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: saranyangj2128122
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 269M/269M [00:02<00:00, 112MB/s]

# %%
data_filename = './us-accidents/US_Accidents_Dec21_updated.csv'

# %% [markdown]
# # **Data Preparation and Cleaning**
#
#
#
# 1.   Load the file using pandas
# 2.   Look at some information about the data & the columns
# 3.   Fixany missing or incoorrect values

# %%
import pandas as pd

# %%
df = pd.read_csv(data_filename)

# %%
df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0              A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1              A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2              A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3              A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# 4              A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43
# ...            ...       ...                  ...                  ...
# 2845337  A-2845338         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
df.shape
# Out:
# (2845342, 47)

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
numerics = ['int16','int32','int64','float16','float32','float64',]
numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %% [markdown]
# # **Percentage of Missing values per column**

# %%
from pandas.core import missing
missing_percentages = df.isna().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# Country                  0.000000e+00
# Junction                 0.000000e+00
# Start_Time               0.000000e+00
# End_Time                 0.000000e+00
# Start_Lat                0.000000e+00
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages != 0]
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# dtype: float64

# %%
missing_percentages[missing_percentages != 0].plot(kind='barh')

# %% [markdown]
# Remove columns that you don't want to use.

# %% [markdown]
# # **Exploratory analysis and Visualization**
#
# Columns we'll analyze.
#
# 1.   City
# 2.   Start TIme
# 3.   Start Lat, Start Lng
# 4.   Temperature
# 5.   Weather Condition

# %% [markdown]
# ## 1.City

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
cities = df.City.unique()
len(cities)
# Out:
# 11682

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# Miami           106966
# Los Angeles      68956
# Orlando          54691
# Dallas           41979
# Houston          39448
# Charlotte        33152
# Sacramento       32559
# San Diego        26627
# Raleigh          22840
# Minneapolis      22768
# Portland         20944
# Nashville        20267
# Austin           18301
# Baton Rouge      18182
# Phoenix          17143
# Saint Paul       16869
# New Orleans      16251
# Atlanta          15622
# Jacksonville     14967
# Richmond         14349
# Name: City, dtype: int64

# %%
type(cities_by_accident)
# Out:
# pandas.core.series.Series

# %%
cities_by_accident[:20].plot(kind='barh')

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.histplot(cities_by_accident, log_scale=True)

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# Carney                          1
# Waverly Hall                    1
# Center Sandwich                 1
# Glen Flora                      1
# Sulphur Springs                 1
#                                ..
# Ridgedale                       1
# Sekiu                           1
# Wooldridge                      1
# Bullock                         1
# American Fork-Pleasant Grove    1
# Name: City, Length: 1110, dtype: int64

# %% [markdown]
# ## Start Time

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)

# %% [markdown]
# *   Figure out how to show percentages

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - A high percentage of accidents occur between 6 am to 10 am (probably people in a hurry to get to work)
# - Next highest percentage is 3 pm to 6 pm.

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as on weekdays.

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]
sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# On Sundays, the peak occurs between 10 am and 3 pm, unlike weekdays

# %%
df_2019 = df[df.Start_Time.dt.year == 2019]
sns.distplot(df_2019.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Can you explain the month-wise trend of accidents?
#
#
# *   Much data is missing for 2016. Maybe even 2017.
#
# *   Change the year and see how the plot is been Created.
# *   Here we can see the percentage of month wise accidents occured.

# %% [markdown]
# ## Start Latitide & Longitude

# %%
df.Start_Lat
# Out:
# 0          40.108910
# 1          39.865420
# 2          39.102660
# 3          41.062130
# 4          39.172393
#              ...
# 2845337    34.002480
# 2845338    32.766960
# 2845339    33.775450
# 2845340    33.992460
# 2845341    34.133930
# Name: Start_Lat, Length: 2845342, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.092860
# 1          -84.062800
# 2          -84.524680
# 3          -81.537840
# 4          -84.492792
#               ...
# 2845337   -117.379360
# 2845338   -117.148060
# 2845339   -117.847790
# 2845340   -118.403020
# 2845341   -117.230920
# Name: Start_Lng, Length: 2845342, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001 )

# %%
import folium

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (40.10891, -83.09286)

# %%
for x in df[['Start_Lat', 'Start_Lng']].sample(100).iteritems():
  print(x[1])
# Out:
# 2287865    33.708580
# 1178187    28.171238
# 2101398    38.916780
# 971469     40.457381
# 1375506    28.285035
#              ...
# 2575732    44.140370
# 2345272    41.242380
# 927491     34.686947
# 2383295    44.884980
# 2298283    40.751790
# Name: Start_Lat, Length: 100, dtype: float64
# 2287865   -117.851610
# 1178187    -82.425404
# 2101398    -76.932640
# 971469    -122.007195
# 1375506    -81.352796
#               ...
# 2575732   -123.052930
# 2345272    -95.953580
# 927491     -86.003306
# 2383295    -93.063680
# 2298283   -111.470810
# Name: Start_Lng, Length: 100, dtype: float64

# %%
zip(list(df.Start_Lat), list(df.Start_Lng))

# %%
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.001 * len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 4. Temperature

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
accident_count1 = df.City.value_counts()


Temp= df.Weather_Condition[:20]


plt.bar(accident_count1[:20],Temp)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# *   Accidents are high in Light Snow and accidents are low in light rain

# %% [markdown]
# ## 5.Weather Condition

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
temperature = df[['Wind_Chill(F)']]
temperature
# Out:
#          Wind_Chill(F)
# 0                 36.1
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                 29.8
# ...                ...
# 2845337           86.0
# 2845338           70.0
# 2845339           73.0
# 2845340           71.0
# 2845341           79.0
#
# [2845342 rows x 1 columns]

# %%
temperature[:20].plot(kind='barh')

# %%
cities_by_accident[:20].plot(kind='barh')

# %%
import matplotlib.pyplot as plt

# %%
accident_count = df.City.value_counts()
accident_count
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
citiesss= df.City[:20]

weatherr = df.Weather_Condition[:30]

plt.scatter(accident_count[:30],weatherr)

# %% [markdown]
# *   In this Weather_condition and number of accidents is been plotted.
# *   Accidents are more in Light Snow, so accidents are more in colder areas.
# *   And accidents are less in light rain.

# %% [markdown]
# ## Which 5 states have higher number of accidents

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
states = df.State.unique()
len(states)
# Out:
# 49

# %%
states_by_accident = df.State.value_counts()
states_by_accident
# Out:
# CA    795868
# FL    401388
# TX    149037
# OR    126341
# VA    113535
# NY    108049
# PA     99975
# MN     97185
# NC     91362
# SC     89216
# MD     65085
# AZ     56504
# NJ     52902
# TN     52613
# UT     49193
# LA     47232
# IL     47105
# MI     43843
# GA     40086
# WA     32554
# CT     29762
# MO     29633
# CO     25340
# OH     24409
# IN     20850
# AL     19322
# MT     15964
# AR     10935
# IA      9607
# DC      9133
# KS      9033
# OK      8806
# ID      8544
# WI      7896
# WV      7632
# KY      6638
# MA      6392
# NV      6197
# MS      5320
# DE      4842
# RI      4451
# NH      3866
# NE      3320
# NM      2370
# ND      2258
# ME      2193
# WY       990
# VT       365
# SD       201
# Name: State, dtype: int64

# %%
states_by_accident[:20]
# Out:
# CA    795868
# FL    401388
# TX    149037
# OR    126341
# VA    113535
# NY    108049
# PA     99975
# MN     97185
# NC     91362
# SC     89216
# MD     65085
# AZ     56504
# NJ     52902
# TN     52613
# UT     49193
# LA     47232
# IL     47105
# MI     43843
# GA     40086
# WA     32554
# Name: State, dtype: int64

# %%
type(states_by_accident)
# Out:
# pandas.core.series.Series

# %%
states_by_accident[:20].plot(kind='barh')

# %% [markdown]
#   - We can see state-wise accidents and its counts
#   - In this the top three states which have highest count of accidents are CA,FL and TX

# %%
sns.histplot(states_by_accident, log_scale=True)

# %% [markdown]
# ## Comparing cities and states

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
a = df.State.value_counts()

regions = ["CA","FL","TX","OR","VA"]
plt.pie(a[:5],labels=regions)
plt.legend()

# %% [markdown]
#   - This is the pie chart for States which have highest accidents.

# %%
b = df.City.value_counts()
region = ["Miami","Los Angeles","Orlando","Dallas","Houston"]
plt.pie(b[:5],labels=region)
plt.legend()

# %% [markdown]
# # **Ask & answer Questions**
#
# 1.   Are there more accidents in warmer or colder areas? - ANSWERED
# 2.   Which 5 states have the highest number of accidents? How about per Capita? - ANSWERED
# 3.   Does New York show up in the data? If yes, why is the count lower if this is the most populated city? - ANSWERED
# 4.   Among the top 100 cities in number of accidents, which states do they belong to most frequenly. - ANSWERED
# 5.   What time of the day are accidents most frequent in? - ANSWERED
# 6.   Which days of the week have the most accidents? - ANSWERED
# 7.   Which months have the most accidents? - ANSWERED
# 8.   Which is the trend of accidents year over year (decreasing/increasing?) - ANSWERED
# 9.   When is accidents per unit of traffic the highest. - ANSWERED

# %% [markdown]
# # Recommendations
#
#
# 1.   Here in miami the accidents are more so we have to concentrate more on this city.
# 2.   Same as for top five cities and states which have higher number of accidents.

# %% [markdown]
# # **Summary and Conclusion**
#
# Insights:
#
# - No data from New York
# - The number of accidents per city decreases exponentially.
# - Less than 5% of cities have more than 1000 yearly accidents.
# - Over 1200 cities have reported just one accident (need to investigate)
# - Miami city has the highest accident occured city.
# - A high percentage of accidents occur between 6 am to 10 am (probably people in a hurry to get to work)
# - Next highest percentage is 3 pm to 6 pm.
# - On Sundays, the peak occurs between 10 am and 3 pm, unlike weekdays
#
# ### So by analysing these things we can reduce the accidents in many cities and states.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# Committed successfully! https://jovian.ai/saranyan-g/us-accidents-analysis
# 'https://jovian.ai/saranyan-g/us-accidents-analysis'
